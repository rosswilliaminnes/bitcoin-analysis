# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
btc = pd.read_csv('~/Desktop/btc.csv')

# %%
btc.head()
# Out:
#    Period        Date   Price    Open    High     Low  change
# 0       1  24/05/2017  1883.8  1751.4  1914.3  1751.4    7.56
# 1       2  25/05/2017  1816.0  1883.8  2176.1  1755.5   -3.60
# 2       3  26/05/2017  1778.7  1834.2  2081.9  1601.3   -2.05
# 3       4  27/05/2017  1658.7  1776.4  1842.9  1487.1   -6.75
# 4       5  28/05/2017  1752.2  1658.7  1843.3  1658.7    5.64

# %%
btc.dtypes
# Out:
# Period      int64
# Date       object
# Price     float64
# Open      float64
# High      float64
# Low       float64
# change    float64
# dtype: object

# %%
# if numbers are strings you may need to execute this code:
# note you may dt['Price'] = dt['Price'].str.replace(',', '')

# dt['Price']=dt['Price'].astype(float)

# %%
plt.plot(btc['Price'])
plt.show()

# %%
from datetime import datetime

# %%
x=[datetime.strptime(d,'%d/%m/%Y') for d in btc['Date']]

plt.plot(x, btc['Price'])

# %%
rm = pd.rolling_mean(btc['Price'],10)
# Out:
# C:\Users\rosinnes\anaconda2\envs\py35\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(x,rm, 'blue')
plt.plot(x,btc['Price'],'red')
plt.show()

# %%
print('hello world')
# Out:
# hello world

# %%
# adding some more code from a different device

# %%
import random

# %%
avec = random.sample(range(0,100),10)

# %%
avec
# Out:
# [83, 67, 17, 12, 87, 77, 15, 92, 13, 91]

# %%
a = []
for i in range(5):    
    a.append(i)
print(a)
# Out:
# [0, 1, 2, 3, 4]

# %%
avec
# Out:
# [83, 67, 17, 12, 87, 77, 15, 92, 13, 91]
